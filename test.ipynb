# %%
import pandas as pd
import sqlite3
from lunar_python import Lunar,LunarYear

# %%
n=LunarYear(1979)

# %%
[l.toString() for l in n.getMonths()]
# Out:
# ['1978年冬月(30天)',
#  '1978年腊月(29天)',
#  '1979年正月(30天)',
#  '1979年二月(29天)',
#  '1979年三月(29天)',
#  '1979年四月(30天)',
#  '1979年五月(29天)',
#  '1979年六月(30天)',
#  '1979年闰六月(30天)',
#  '1979年七月(29天)',
#  '1979年八月(30天)',
#  '1979年九月(30天)',
#  '1979年十月(29天)',
#  '1979年冬月(30天)',
#  '1979年腊月(29天)']
